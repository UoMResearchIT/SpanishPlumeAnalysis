# %%
import xarray as xr
import matplotlib.pyplot as plt
import ipywidgets as widgets
import numpy as np

from ipywidget import view_wrf_3d, view_wrf_2d

# %%
ds = xr.open_dataset("/mnt/projects/wrf-storm-workshop/data/wrfout/arwen_ctrl/d01/wrfout_d01_2021-11-26_00:00:00", engine="netcdf4")
# print(ds.data_vars)

# %%
varname = "U10"
view_wrf_2d(da)

# %%
varname = "U"
da = ds[varname].isel(Time=0, drop=True)
view_wrf_3d(da)
# Out:
# interactive(children=(IntSlider(value=0, description='level', max=58), Output()), _dom_classes=('widget-intera…
